# %% [markdown]
# Dependent variable: GHI

# %% [markdown]
# Data Summary and Pearson Correlation matrix

# %% [markdown]
# This code block is for **Initial Data Loading and Overview**.
#
# *   `import pandas as pd`: Imports the pandas library, essential for data manipulation.
# *   `df = pd.read_csv("/content/qbmult_dataset.csv")`: Loads your dataset into a pandas DataFrame named `df`.
# *   `print(df.shape)`: Displays the number of rows and columns in the dataset.
# *   `print(df.head())`: Shows the first 5 rows of the DataFrame, giving a quick glance at the data structure and content.
# *   `print(df[["ARMS","AGE","BMI","SEX","IPAQ"]].describe())`: Generates descriptive statistics (count, mean, std, min, max, quartiles) for the selected columns. This helps understand the distribution and central tendencies of your variables.
# *   `print(df[["ARMS","AGE","BMI","SEX","IPAQ"]].corr())`: Computes the Pearson correlation matrix for the specified variables. This matrix shows the linear relationship between each pair of variables. In regression, it helps identify potential predictors that have a linear association with the dependent variable ('ARMS' in this case).
#
# **Role in Regression:** These steps are crucial for understanding your data before building any model. They help you get acquainted with the variables, identify potential issues (like missing values, outliers, or unusual distributions), and see initial linear relationships between variables.

# %%
import pandas as pd
from scipy.stats import shapiro

# Load your data
ny_df = pd.read_csv("/content/merged_climate_data_ny.csv")

print(ny_df.shape)
print(ny_df.head())

# summary and correlations
print(ny_df[["Temperature",	"Aerosol Optical Depth",	"Clearsky DHI",	"Clearsky DNI",	"Clearsky GHI",	"Dew Point",	"DHI",	"DNI",	"GHI",	"Ozone",	"Relative Humidity",	"Solar Zenith Angle",	"SSA",	"Surface Albedo",	"Pressure", "Precipitable Water",	"Wind Direction",	"Wind Speed",	"Global Horizontal UV Irradiance (280-400nm)",	"Global Horizontal UV Irradiance (295-385nm)"]].describe())

print(ny_df[["Temperature",	"Aerosol Optical Depth",	"Clearsky DHI",	"Clearsky DNI",	"Clearsky GHI",	"Dew Point",	"DHI",	"DNI",	"GHI",	"Ozone",	"Relative Humidity",	"Solar Zenith Angle",	"SSA",	"Surface Albedo",	"Pressure", "Precipitable Water",	"Wind Direction",	"Wind Speed",	"Global Horizontal UV Irradiance (280-400nm)",	"Global Horizontal UV Irradiance (295-385nm)"]].corr())
# Out:
# (27, 22)
#    Temperature  Aerosol Optical Depth  Asymmetry  Clearsky DHI  Clearsky DNI  \
# 0    12.333025               0.136093   0.603205        409824       2932373
# 1    12.130434               0.122649   0.603205        394224       2996437
# 2    10.853801               0.151425   0.603205        438790       2882084
# 3    12.058253               0.155152   0.603205        438009       2890204
# 4    12.396998               0.159737   0.603205        441016       2872791
#
#    Clearsky GHI  Dew Point     DHI      DNI      GHI  ...  Solar Zenith Angle  \
# 0       2024090   8.274749  607151  1589904  1501006  ...           89.657107
# 1       2042209   7.331290  592255  1785651  1589653  ...           89.657277
# 2       2021066   6.903584  642188  1584831  1509155  ...           89.689491
# 3       2028549   7.229737  626211  1735309  1598940  ...           89.657639
# 4       2017182   7.480947  633958  1642748  1561889  ...           89.657663
#
#         SSA  Surface Albedo     Pressure  Precipitable Water  Wind Direction  \
# 0  0.944634        0.073616  1014.075228            2.059589      206.121918
# 1  0.946338        0.076849  1015.326826            1.931655      205.129909
# 2  0.948031        0.129397  1015.289041            1.977534      206.482192
# 3  0.942675        0.126356  1015.489384            1.877785      210.213927
# 4  0.939269        0.097205  1015.271689            2.004075      210.686758
#
#    Wind Speed  Global Horizontal UV Irradiance (280-400nm)  \
# 0    2.277717                                   84254.7112
# 1    2.438208                                   89209.9887
# 2    2.402511                                   84675.6378
# 3    2.234212                                   89718.0624
# 4    2.410491                                   87641.0280
#
#    Global Horizontal UV Irradiance (295-385nm)  Year
# 0                                   65990.9163  1998
# 1                                   69872.0801  1999
# 2                                   66309.0552  2000
# 3                                   70267.4083  2001
# 4                                   68647.5712  2002
#
# [5 rows x 22 columns]
#        Temperature  Aerosol Optical Depth   Clearsky DHI  Clearsky DNI  \
# count    27.000000              27.000000      27.000000  2.700000e+01
# mean     11.937903               0.137030  415994.592593  2.922834e+06
# std       0.638105               0.015832   20579.323324  4.970088e+04
# min      10.588527               0.113417  379813.000000  2.820769e+06
# 25%      11.652671               0.122459  397834.500000  2.887178e+06
# 50%      12.035833               0.135594  409939.000000  2.917497e+06
# 75%      12.365011               0.149557  430761.500000  2.964661e+06
# max      12.944326               0.164721  460958.000000  3.009470e+06
#
#        Clearsky GHI  Dew Point            DHI           DNI           GHI  \
# count  2.700000e+01  27.000000      27.000000  2.700000e+01  2.700000e+01
# mean   2.023211e+06   8.070357  624842.333333  1.503138e+06  1.472056e+06
# std    8.866378e+03   0.683180   48211.985775  1.379306e+05  6.427598e+04
# min    2.009153e+06   6.830057  533885.000000  1.284494e+06  1.314211e+06
# 25%    2.016904e+06   7.632905  593395.000000  1.409616e+06  1.431207e+06
# 50%    2.021066e+06   7.914555  626211.000000  1.509102e+06  1.478612e+06
# 75%    2.029890e+06   8.707791  647325.500000  1.587368e+06  1.509034e+06
# max    2.042209e+06   9.319372  715198.000000  1.785651e+06  1.598940e+06
#
#            Ozone  Relative Humidity  Solar Zenith Angle        SSA  \
# count  27.000000          27.000000           27.000000  27.000000
# mean    0.318857          79.260992           89.665968   0.936683
# std     0.005170           2.187101            0.014457   0.004867
# min     0.309222          74.923473           89.657018   0.930409
# 25%     0.315601          78.469277           89.657496   0.933233
# 50%     0.317785          79.054800           89.657670   0.935155
# 75%     0.320963          80.881344           89.673899   0.939463
# max     0.333537          82.964814           89.690812   0.948031
#
#        Surface Albedo     Pressure  Precipitable Water  Wind Direction  \
# count       27.000000    27.000000           27.000000       27.000000
# mean         0.118827  1014.945819            2.102144      205.267728
# std          0.027945     0.895729            0.104097        5.599962
# min          0.073616  1011.824658            1.877785      194.877968
# 25%          0.095877  1014.510103            2.033299      201.931906
# 50%          0.124082  1015.131849            2.093756      205.129909
# 75%          0.133164  1015.450400            2.155776      209.543151
# max          0.172849  1016.366553            2.357842      220.440753
#
#        Wind Speed  Global Horizontal UV Irradiance (280-400nm)  \
# count   27.000000                                    27.000000
# mean     2.374088                                 82667.858733
# std      0.079190                                  3640.863514
# min      2.234212                                 73705.570800
# 25%      2.318790                                 80300.912250
# 50%      2.361849                                 83067.640500
# 75%      2.416033                                 84758.532150
# max      2.560320                                 89718.062400
#
#        Global Horizontal UV Irradiance (295-385nm)
# count                                    27.000000
# mean                                  64749.274341
# std                                    2852.257569
# min                                   57729.626000
# 25%                                   62897.635950
# 50%                                   65072.933600
# 75%                                   66382.727700
# max                                   70267.408300
#                                              Temperature  \
# Temperature                                     1.000000
# Aerosol Optical Depth                          -0.197294
# Clearsky DHI                                   -0.379959
# Clearsky DNI                                    0.263769
# Clearsky GHI                                   -0.066787
# Dew Point                                       0.703338
# DHI                                            -0.494297
# DNI                                             0.449569
# GHI                                             0.181431
# Ozone                                          -0.095066
# Relative Humidity                              -0.264472
# Solar Zenith Angle                              0.189404
# SSA                                            -0.425474
# Surface Albedo                                 -0.558139
# Pressure                                       -0.213358
# Precipitable Water                              0.246499
# Wind Direction                                  0.021515
# Wind Speed                                      0.042175
# Global Horizontal UV Irradiance (280-400nm)     0.174213
# Global Horizontal UV Irradiance (295-385nm)     0.174555
#
#                                              Aerosol Optical Depth  \
# Temperature                                              -0.197294
# Aerosol Optical Depth                                     1.000000
# Clearsky DHI                                              0.969922
# Clearsky DNI                                             -0.953985
# Clearsky GHI                                             -0.709681
# Dew Point                                                -0.053241
# DHI                                                       0.101896
# DNI                                                       0.012462
# GHI                                                       0.066207
# Ozone                                                    -0.073584
# Relative Humidity                                         0.193822
# Solar Zenith Angle                                       -0.068975
# SSA                                                       0.440321
# Surface Albedo                                            0.053927
# Pressure                                                 -0.123590
# Precipitable Water                                       -0.243394
# Wind Direction                                            0.004917
# Wind Speed                                               -0.374063
# Global Horizontal UV Irradiance (280-400nm)               0.065925
# Global Horizontal UV Irradiance (295-385nm)               0.065745
#
#                                              Clearsky DHI  Clearsky DNI  \
# Temperature                                     -0.379959      0.263769
# Aerosol Optical Depth                            0.969922     -0.953985
# Clearsky DHI                                     1.000000     -0.968575
# Clearsky DNI                                    -0.968575      1.000000
# Clearsky GHI                                    -0.688842      0.835877
# Dew Point                                       -0.158846     -0.052561
# DHI                                              0.150488     -0.053540
# DNI                                             -0.079902      0.157512
# GHI                                             -0.020869      0.185622
# Ozone                                           -0.040389      0.089727
# Relative Humidity                                0.272639     -0.413792
# Solar Zenith Angle                              -0.104340      0.013558
# SSA                                              0.497971     -0.398858
# Surface Albedo                                   0.196535     -0.114865
# Pressure                                        -0.042423      0.049611
# Precipitable Water                              -0.220098      0.035098
# Wind Direction                                  -0.042961      0.121477
# Wind Speed                                      -0.291490      0.253410
# Global Horizontal UV Irradiance (280-400nm)     -0.021648      0.185171
# Global Horizontal UV Irradiance (295-385nm)     -0.021997      0.185405
#
#                                              Clearsky GHI  Dew Point  \
# Temperature                                     -0.066787   0.703338
# Aerosol Optical Depth                           -0.709681  -0.053241
# Clearsky DHI                                    -0.688842  -0.158846
# Clearsky DNI                                     0.835877  -0.052561
# Clearsky GHI                                     1.000000  -0.517816
# Dew Point                                       -0.517816   1.000000
# DHI                                              0.210019  -0.396680
# DNI                                              0.250329  -0.160607
# GHI                                              0.498074  -0.491712
# Ozone                                            0.088254  -0.165829
# Relative Humidity                               -0.629091   0.497925
# Solar Zenith Angle                              -0.178964   0.148002
# SSA                                             -0.058267  -0.518137
# Surface Albedo                                   0.036176  -0.258157
# Pressure                                         0.058095  -0.194561
# Precipitable Water                              -0.424904   0.746997
# Wind Direction                                   0.261554  -0.187190
# Wind Speed                                      -0.002028   0.119650
# Global Horizontal UV Irradiance (280-400nm)      0.499143  -0.495227
# Global Horizontal UV Irradiance (295-385nm)      0.499236  -0.494964
#
#                                                   DHI       DNI       GHI  \
# Temperature                                 -0.494297  0.449569  0.181431
# Aerosol Optical Depth                        0.101896  0.012462  0.066207
# Clearsky DHI                                 0.150488 -0.079902 -0.020869
# Clearsky DNI                                -0.053540  0.157512  0.185622
# Clearsky GHI                                 0.210019  0.250329  0.498074
# Dew Point                                   -0.396680 -0.160607 -0.491712
# DHI                                          1.000000 -0.568088  0.115753
# DNI                                         -0.568088  1.000000  0.740893
# GHI                                          0.115753  0.740893  1.000000
# Ozone                                       -0.024085  0.161111  0.095205
# Relative Humidity                            0.082910 -0.769580 -0.879796
# Solar Zenith Angle                          -0.184914  0.158327  0.035753
# SSA                                          0.019950  0.262966  0.250361
# Surface Albedo                               0.465621 -0.482483 -0.236587
# Pressure                                    -0.121393  0.016918 -0.059202
# Precipitable Water                          -0.271897 -0.490809 -0.798020
# Wind Direction                               0.416827 -0.004561  0.350928
# Wind Speed                                  -0.522001  0.078573 -0.359145
# Global Horizontal UV Irradiance (280-400nm)  0.125515  0.730824  0.999367
# Global Horizontal UV Irradiance (295-385nm)  0.125725  0.730455  0.999318
#
#                                                 Ozone  Relative Humidity  \
# Temperature                                 -0.095066          -0.264472
# Aerosol Optical Depth                       -0.073584           0.193822
# Clearsky DHI                                -0.040389           0.272639
# Clearsky DNI                                 0.089727          -0.413792
# Clearsky GHI                                 0.088254          -0.629091
# Dew Point                                   -0.165829           0.497925
# DHI                                         -0.024085           0.082910
# DNI                                          0.161111          -0.769580
# GHI                                          0.095205          -0.879796
# Ozone                                        1.000000          -0.107315
# Relative Humidity                           -0.107315           1.000000
# Solar Zenith Angle                          -0.018158          -0.047314
# SSA                                          0.099922          -0.167557
# Surface Albedo                               0.169312           0.343234
# Pressure                                    -0.255841          -0.021340
# Precipitable Water                          -0.100273           0.704719
# Wind Direction                               0.052202          -0.278821
# Wind Speed                                   0.082258           0.097468
# Global Horizontal UV Irradiance (280-400nm)  0.083250          -0.875949
# Global Horizontal UV Irradiance (295-385nm)  0.082691          -0.876004
#
#                                              Solar Zenith Angle       SSA  \
# Temperature                                            0.189404 -0.425474
# Aerosol Optical Depth                                 -0.068975  0.440321
# Clearsky DHI                                          -0.104340  0.497971
# Clearsky DNI                                           0.013558 -0.398858
# Clearsky GHI                                          -0.178964 -0.058267
# Dew Point                                              0.148002 -0.518137
# DHI                                                   -0.184914  0.019950
# DNI                                                    0.158327  0.262966
# GHI                                                    0.035753  0.250361
# Ozone                                                 -0.018158  0.099922
# Relative Humidity                                     -0.047314 -0.167557
# Solar Zenith Angle                                     1.000000 -0.032731
# SSA                                                   -0.032731  1.000000
# Surface Albedo                                        -0.219591 -0.151058
# Pressure                                               0.098873  0.102302
# Precipitable Water                                     0.040800 -0.533345
# Wind Direction                                        -0.320357 -0.026026
# Wind Speed                                            -0.001908 -0.066673
# Global Horizontal UV Irradiance (280-400nm)            0.048322  0.242638
# Global Horizontal UV Irradiance (295-385nm)            0.048353  0.241758
#
#                                              Surface Albedo  Pressure  \
# Temperature                                       -0.558139 -0.213358
# Aerosol Optical Depth                              0.053927 -0.123590
# Clearsky DHI                                       0.196535 -0.042423
# Clearsky DNI                                      -0.114865  0.049611
# Clearsky GHI                                       0.036176  0.058095
# Dew Point                                         -0.258157 -0.194561
# DHI                                                0.465621 -0.121393
# DNI                                               -0.482483  0.016918
# GHI                                               -0.236587 -0.059202
# Ozone                                              0.169312 -0.255841
# Relative Humidity                                  0.343234 -0.021340
# Solar Zenith Angle                                -0.219591  0.098873
# SSA                                               -0.151058  0.102302
# Surface Albedo                                     1.000000  0.089948
# Pressure                                           0.089948  1.000000
# Precipitable Water                                 0.174182  0.180113
# Wind Direction                                    -0.080443 -0.375446
# Wind Speed                                        -0.092506  0.255826
# Global Horizontal UV Irradiance (280-400nm)       -0.236892 -0.055850
# Global Horizontal UV Irradiance (295-385nm)       -0.237244 -0.055716
#
#                                              Precipitable Water  \
# Temperature                                            0.246499
# Aerosol Optical Depth                                 -0.243394
# Clearsky DHI                                          -0.220098
# Clearsky DNI                                           0.035098
# Clearsky GHI                                          -0.424904
# Dew Point                                              0.746997
# DHI                                                   -0.271897
# DNI                                                   -0.490809
# GHI                                                   -0.798020
# Ozone                                                 -0.100273
# Relative Humidity                                      0.704719
# Solar Zenith Angle                                     0.040800
# SSA                                                   -0.533345
# Surface Albedo                                         0.174182
# Pressure                                               0.180113
# Precipitable Water                                     1.000000
# Wind Direction                                        -0.369174
# Wind Speed                                             0.429119
# Global Horizontal UV Irradiance (280-400nm)           -0.800823
# Global Horizontal UV Irradiance (295-385nm)           -0.800639
#
#                                              Wind Direction  Wind Speed  \
# Temperature                                        0.021515    0.042175
# Aerosol Optical Depth                              0.004917   -0.374063
# Clearsky DHI                                      -0.042961   -0.291490
# Clearsky DNI                                       0.121477    0.253410
# Clearsky GHI                                       0.261554   -0.002028
# Dew Point                                         -0.187190    0.119650
# DHI                                                0.416827   -0.522001
# DNI                                               -0.004561    0.078573
# GHI                                                0.350928   -0.359145
# Ozone                                              0.052202    0.082258
# Relative Humidity                                 -0.278821    0.097468
# Solar Zenith Angle                                -0.320357   -0.001908
# SSA                                               -0.026026   -0.066673
# Surface Albedo                                    -0.080443   -0.092506
# Pressure                                          -0.375446    0.255826
# Precipitable Water                                -0.369174    0.429119
# Wind Direction                                     1.000000   -0.179718
# Wind Speed                                        -0.179718    1.000000
# Global Horizontal UV Irradiance (280-400nm)        0.351831   -0.371002
# Global Horizontal UV Irradiance (295-385nm)        0.352022   -0.371254
#
#                                              Global Horizontal UV Irradiance (280-400nm)  \
# Temperature                                                                     0.174213
# Aerosol Optical Depth                                                           0.065925
# Clearsky DHI                                                                   -0.021648
# Clearsky DNI                                                                    0.185171
# Clearsky GHI                                                                    0.499143
# Dew Point                                                                      -0.495227
# DHI                                                                             0.125515
# DNI                                                                             0.730824
# GHI                                                                             0.999367
# Ozone                                                                           0.083250
# Relative Humidity                                                              -0.875949
# Solar Zenith Angle                                                              0.048322
# SSA                                                                             0.242638
# Surface Albedo                                                                 -0.236892
# Pressure                                                                       -0.055850
# Precipitable Water                                                             -0.800823
# Wind Direction                                                                  0.351831
# Wind Speed                                                                     -0.371002
# Global Horizontal UV Irradiance (280-400nm)                                     1.000000
# Global Horizontal UV Irradiance (295-385nm)                                     0.999998
#
#                                              Global Horizontal UV Irradiance (295-385nm)
# Temperature                                                                     0.174555
# Aerosol Optical Depth                                                           0.065745
# Clearsky DHI                                                                   -0.021997
# Clearsky DNI                                                                    0.185405
# Clearsky GHI                                                                    0.499236
# Dew Point                                                                      -0.494964
# DHI                                                                             0.125725
# DNI                                                                             0.730455
# GHI                                                                             0.999318
# Ozone                                                                           0.082691
# Relative Humidity                                                              -0.876004
# Solar Zenith Angle                                                              0.048353
# SSA                                                                             0.241758
# Surface Albedo                                                                 -0.237244
# Pressure                                                                       -0.055716
# Precipitable Water                                                             -0.800639
# Wind Direction                                                                  0.352022
# Wind Speed                                                                     -0.371254
# Global Horizontal UV Irradiance (280-400nm)                                     0.999998
# Global Horizontal UV Irradiance (295-385nm)                                     1.000000

# %% [markdown]
# Check Linearity between dependent and predictor variables: Spearman Correlation Matrix

# %% [markdown]
# This code block calculates the **Spearman Rank-Order Correlation**.
#
# *   `from scipy.stats import spearmanr`: Imports the `spearmanr` function for calculating Spearman correlation.
# *   `vars = [...]`: Defines a list of variables to be analyzed.
# *   `data = df[vars].dropna()`: Selects the specified columns and drops any rows with missing values to ensure accurate correlation calculation.
# *   `corr, pval = spearmanr(data)`: Computes the Spearman correlation coefficients and p-values. Spearman correlation assesses the monotonic relationship between ranked data, which is less sensitive to outliers and non-normal distributions than Pearson correlation.
# *   `corr_matrix = pd.DataFrame(corr, index=vars, columns=vars)`: Organizes the correlation results into a DataFrame for better readability.
# *   `print(corr_matrix.round(3))`: Prints the Spearman correlation matrix, rounded to three decimal places.
#
# **Role in Regression:** While linear regression assumes a linear relationship, examining Spearman correlation provides a broader view of monotonic relationships. Strong monotonic relationships suggest that a transformation of variables might lead to better linear fit, or simply confirms that variables move together. It complements Pearson correlation in understanding variable associations.

# %%
import pandas as pd
import numpy as np
from scipy.stats import spearmanr

vars = ["Temperature",	"Aerosol Optical Depth",	"Clearsky DHI",	"Clearsky DNI",	"Clearsky GHI",	"Dew Point",	"DHI",	"DNI",	"GHI",	"Ozone",	"Relative Humidity",	"Solar Zenith Angle",	"SSA",	"Surface Albedo",	"Pressure", "Precipitable Water",	"Wind Direction",	"Wind Speed",	"Global Horizontal UV Irradiance (280-400nm)",	"Global Horizontal UV Irradiance (295-385nm)"]
data = ny_df[vars].dropna()

# Compute Spearman correlations and p-values
corr, pval = spearmanr(data)

# Convert to DataFrames
corr_matrix = pd.DataFrame(corr, index=vars, columns=vars)

print("Spearman Correlation Matrix:")
print(corr_matrix.round(3))
# Out:
# Spearman Correlation Matrix:
#                                              Temperature  \
# Temperature                                        1.000
# Aerosol Optical Depth                             -0.155
# Clearsky DHI                                      -0.323
# Clearsky DNI                                       0.243
# Clearsky GHI                                      -0.093
# Dew Point                                          0.648
# DHI                                               -0.537
# DNI                                                0.455
# GHI                                                0.172
# Ozone                                             -0.258
# Relative Humidity                                 -0.226
# Solar Zenith Angle                                 0.377
# SSA                                               -0.415
# Surface Albedo                                    -0.585
# Pressure                                          -0.266
# Precipitable Water                                 0.300
# Wind Direction                                     0.024
# Wind Speed                                         0.032
# Global Horizontal UV Irradiance (280-400nm)        0.129
# Global Horizontal UV Irradiance (295-385nm)        0.128
#
#                                              Aerosol Optical Depth  \
# Temperature                                                 -0.155
# Aerosol Optical Depth                                        1.000
# Clearsky DHI                                                 0.965
# Clearsky DNI                                                -0.958
# Clearsky GHI                                                -0.704
# Dew Point                                                   -0.094
# DHI                                                          0.159
# DNI                                                          0.074
# GHI                                                          0.059
# Ozone                                                       -0.010
# Relative Humidity                                            0.246
# Solar Zenith Angle                                          -0.308
# SSA                                                          0.539
# Surface Albedo                                               0.058
# Pressure                                                    -0.247
# Precipitable Water                                          -0.225
# Wind Direction                                               0.046
# Wind Speed                                                  -0.341
# Global Horizontal UV Irradiance (280-400nm)                  0.060
# Global Horizontal UV Irradiance (295-385nm)                  0.069
#
#                                              Clearsky DHI  Clearsky DNI  \
# Temperature                                        -0.323         0.243
# Aerosol Optical Depth                               0.965        -0.958
# Clearsky DHI                                        1.000        -0.976
# Clearsky DNI                                       -0.976         1.000
# Clearsky GHI                                       -0.690         0.789
# Dew Point                                          -0.175         0.043
# DHI                                                 0.200        -0.105
# DNI                                                -0.005         0.032
# GHI                                                 0.005         0.106
# Ozone                                               0.014         0.060
# Relative Humidity                                   0.287        -0.375
# Solar Zenith Angle                                 -0.325         0.240
# SSA                                                 0.556        -0.509
# Surface Albedo                                      0.202        -0.118
# Pressure                                           -0.148         0.181
# Precipitable Water                                 -0.218         0.126
# Wind Direction                                     -0.008         0.004
# Wind Speed                                         -0.275         0.245
# Global Horizontal UV Irradiance (280-400nm)         0.015         0.098
# Global Horizontal UV Irradiance (295-385nm)         0.020         0.089
#
#                                              Clearsky GHI  Dew Point    DHI  \
# Temperature                                        -0.093      0.648 -0.537
# Aerosol Optical Depth                              -0.704     -0.094  0.159
# Clearsky DHI                                       -0.690     -0.175  0.200
# Clearsky DNI                                        0.789      0.043 -0.105
# Clearsky GHI                                        1.000     -0.471  0.198
# Dew Point                                          -0.471      1.000 -0.452
# DHI                                                 0.198     -0.452  1.000
# DNI                                                 0.165     -0.159 -0.537
# GHI                                                 0.448     -0.497  0.083
# Ozone                                               0.132     -0.352  0.172
# Relative Humidity                                  -0.655      0.527  0.010
# Solar Zenith Angle                                  0.024      0.270 -0.195
# SSA                                                -0.161     -0.485  0.089
# Surface Albedo                                      0.012     -0.237  0.473
# Pressure                                            0.188     -0.274 -0.173
# Precipitable Water                                 -0.399      0.805 -0.335
# Wind Direction                                      0.206     -0.241  0.396
# Wind Speed                                         -0.070      0.070 -0.433
# Global Horizontal UV Irradiance (280-400nm)         0.467     -0.531  0.122
# Global Horizontal UV Irradiance (295-385nm)         0.459     -0.531  0.117
#
#                                                DNI    GHI  Ozone  \
# Temperature                                  0.455  0.172 -0.258
# Aerosol Optical Depth                        0.074  0.059 -0.010
# Clearsky DHI                                -0.005  0.005  0.014
# Clearsky DNI                                 0.032  0.106  0.060
# Clearsky GHI                                 0.165  0.448  0.132
# Dew Point                                   -0.159 -0.497 -0.352
# DHI                                         -0.537  0.083  0.172
# DNI                                          1.000  0.758  0.101
# GHI                                          0.758  1.000  0.171
# Ozone                                        0.101  0.171  1.000
# Relative Humidity                           -0.698 -0.860 -0.164
# Solar Zenith Angle                           0.134  0.014 -0.170
# SSA                                          0.143  0.145  0.164
# Surface Albedo                              -0.468 -0.244  0.287
# Pressure                                     0.023  0.031  0.022
# Precipitable Water                          -0.433 -0.703 -0.266
# Wind Direction                               0.019  0.358  0.165
# Wind Speed                                   0.039 -0.267  0.131
# Global Horizontal UV Irradiance (280-400nm)  0.720  0.993  0.144
# Global Horizontal UV Irradiance (295-385nm)  0.722  0.991  0.137
#
#                                              Relative Humidity  \
# Temperature                                             -0.226
# Aerosol Optical Depth                                    0.246
# Clearsky DHI                                             0.287
# Clearsky DNI                                            -0.375
# Clearsky GHI                                            -0.655
# Dew Point                                                0.527
# DHI                                                      0.010
# DNI                                                     -0.698
# GHI                                                     -0.860
# Ozone                                                   -0.164
# Relative Humidity                                        1.000
# Solar Zenith Angle                                      -0.166
# SSA                                                      0.012
# Surface Albedo                                           0.264
# Pressure                                                -0.089
# Precipitable Water                                       0.658
# Wind Direction                                          -0.285
# Wind Speed                                               0.082
# Global Horizontal UV Irradiance (280-400nm)             -0.857
# Global Horizontal UV Irradiance (295-385nm)             -0.857
#
#                                              Solar Zenith Angle    SSA  \
# Temperature                                               0.377 -0.415
# Aerosol Optical Depth                                    -0.308  0.539
# Clearsky DHI                                             -0.325  0.556
# Clearsky DNI                                              0.240 -0.509
# Clearsky GHI                                              0.024 -0.161
# Dew Point                                                 0.270 -0.485
# DHI                                                      -0.195  0.089
# DNI                                                       0.134  0.143
# GHI                                                       0.014  0.145
# Ozone                                                    -0.170  0.164
# Relative Humidity                                        -0.166  0.012
# Solar Zenith Angle                                        1.000 -0.489
# SSA                                                      -0.489  1.000
# Surface Albedo                                           -0.104 -0.082
# Pressure                                                  0.128  0.092
# Precipitable Water                                        0.161 -0.507
# Wind Direction                                           -0.106 -0.015
# Wind Speed                                                0.042 -0.005
# Global Horizontal UV Irradiance (280-400nm)               0.005  0.155
# Global Horizontal UV Irradiance (295-385nm)               0.010  0.148
#
#                                              Surface Albedo  Pressure  \
# Temperature                                          -0.585    -0.266
# Aerosol Optical Depth                                 0.058    -0.247
# Clearsky DHI                                          0.202    -0.148
# Clearsky DNI                                         -0.118     0.181
# Clearsky GHI                                          0.012     0.188
# Dew Point                                            -0.237    -0.274
# DHI                                                   0.473    -0.173
# DNI                                                  -0.468     0.023
# GHI                                                  -0.244     0.031
# Ozone                                                 0.287     0.022
# Relative Humidity                                     0.264    -0.089
# Solar Zenith Angle                                   -0.104     0.128
# SSA                                                  -0.082     0.092
# Surface Albedo                                        1.000     0.098
# Pressure                                              0.098     1.000
# Precipitable Water                                    0.127     0.109
# Wind Direction                                       -0.104    -0.096
# Wind Speed                                           -0.035     0.420
# Global Horizontal UV Irradiance (280-400nm)          -0.232     0.026
# Global Horizontal UV Irradiance (295-385nm)          -0.250     0.026
#
#                                              Precipitable Water  \
# Temperature                                               0.300
# Aerosol Optical Depth                                    -0.225
# Clearsky DHI                                             -0.218
# Clearsky DNI                                              0.126
# Clearsky GHI                                             -0.399
# Dew Point                                                 0.805
# DHI                                                      -0.335
# DNI                                                      -0.433
# GHI                                                      -0.703
# Ozone                                                    -0.266
# Relative Humidity                                         0.658
# Solar Zenith Angle                                        0.161
# SSA                                                      -0.507
# Surface Albedo                                            0.127
# Pressure                                                  0.109
# Precipitable Water                                        1.000
# Wind Direction                                           -0.407
# Wind Speed                                                0.293
# Global Horizontal UV Irradiance (280-400nm)              -0.737
# Global Horizontal UV Irradiance (295-385nm)              -0.742
#
#                                              Wind Direction  Wind Speed  \
# Temperature                                           0.024       0.032
# Aerosol Optical Depth                                 0.046      -0.341
# Clearsky DHI                                         -0.008      -0.275
# Clearsky DNI                                          0.004       0.245
# Clearsky GHI                                          0.206      -0.070
# Dew Point                                            -0.241       0.070
# DHI                                                   0.396      -0.433
# DNI                                                   0.019       0.039
# GHI                                                   0.358      -0.267
# Ozone                                                 0.165       0.131
# Relative Humidity                                    -0.285       0.082
# Solar Zenith Angle                                   -0.106       0.042
# SSA                                                  -0.015      -0.005
# Surface Albedo                                       -0.104      -0.035
# Pressure                                             -0.096       0.420
# Precipitable Water                                   -0.407       0.293
# Wind Direction                                        1.000      -0.209
# Wind Speed                                           -0.209       1.000
# Global Horizontal UV Irradiance (280-400nm)           0.383      -0.317
# Global Horizontal UV Irradiance (295-385nm)           0.387      -0.325
#
#                                              Global Horizontal UV Irradiance (280-400nm)  \
# Temperature                                                                        0.129
# Aerosol Optical Depth                                                              0.060
# Clearsky DHI                                                                       0.015
# Clearsky DNI                                                                       0.098
# Clearsky GHI                                                                       0.467
# Dew Point                                                                         -0.531
# DHI                                                                                0.122
# DNI                                                                                0.720
# GHI                                                                                0.993
# Ozone                                                                              0.144
# Relative Humidity                                                                 -0.857
# Solar Zenith Angle                                                                 0.005
# SSA                                                                                0.155
# Surface Albedo                                                                    -0.232
# Pressure                                                                           0.026
# Precipitable Water                                                                -0.737
# Wind Direction                                                                     0.383
# Wind Speed                                                                        -0.317
# Global Horizontal UV Irradiance (280-400nm)                                        1.000
# Global Horizontal UV Irradiance (295-385nm)                                        0.999
#
#                                              Global Horizontal UV Irradiance (295-385nm)
# Temperature                                                                        0.128
# Aerosol Optical Depth                                                              0.069
# Clearsky DHI                                                                       0.020
# Clearsky DNI                                                                       0.089
# Clearsky GHI                                                                       0.459
# Dew Point                                                                         -0.531
# DHI                                                                                0.117
# DNI                                                                                0.722
# GHI                                                                                0.991
# Ozone                                                                              0.137
# Relative Humidity                                                                 -0.857
# Solar Zenith Angle                                                                 0.010
# SSA                                                                                0.148
# Surface Albedo                                                                    -0.250
# Pressure                                                                           0.026
# Precipitable Water                                                                -0.742
# Wind Direction                                                                     0.387
# Wind Speed                                                                        -0.325
# Global Horizontal UV Irradiance (280-400nm)                                        0.999
# Global Horizontal UV Irradiance (295-385nm)                                        1.000

# %%
import pandas as pd
from scipy.stats import shapiro

# Load your data
ny_df = pd.read_csv("/content/merged_climate_data_ny.csv")

print(ny_df.shape)
print(ny_df.head())

# summary and correlations
print(ny_df[["Temperature",	"Aerosol Optical Depth",	"Clearsky DHI",	"Clearsky DNI",	"Clearsky GHI",	"Dew Point",	"DHI",	"DNI",	"GHI",	"Ozone",	"Relative Humidity",	"Solar Zenith Angle",	"SSA",	"Surface Albedo",	"Pressure", "Precipitable Water",	"Wind Direction",	"Wind Speed",	"Global Horizontal UV Irradiance (280-400nm)",	"Global Horizontal UV Irradiance (295-385nm)"]].describe())

print(ny_df[["Temperature",	"Aerosol Optical Depth",	"Clearsky DHI",	"Clearsky DNI",	"Clearsky GHI",	"Dew Point",	"DHI",	"DNI",	"GHI",	"Ozone",	"Relative Humidity",	"Solar Zenith Angle",	"SSA",	"Surface Albedo",	"Pressure", "Precipitable Water",	"Wind Direction",	"Wind Speed",	"Global Horizontal UV Irradiance (280-400nm)",	"Global Horizontal UV Irradiance (295-385nm)"]].corr())
# Out:
# (27, 22)
#    Temperature  Aerosol Optical Depth  Asymmetry  Clearsky DHI  Clearsky DNI  \
# 0    12.333025               0.136093   0.603205        409824       2932373
# 1    12.130434               0.122649   0.603205        394224       2996437
# 2    10.853801               0.151425   0.603205        438790       2882084
# 3    12.058253               0.155152   0.603205        438009       2890204
# 4    12.396998               0.159737   0.603205        441016       2872791
#
#    Clearsky GHI  Dew Point     DHI      DNI      GHI  ...  Solar Zenith Angle  \
# 0       2024090   8.274749  607151  1589904  1501006  ...           89.657107
# 1       2042209   7.331290  592255  1785651  1589653  ...           89.657277
# 2       2021066   6.903584  642188  1584831  1509155  ...           89.689491
# 3       2028549   7.229737  626211  1735309  1598940  ...           89.657639
# 4       2017182   7.480947  633958  1642748  1561889  ...           89.657663
#
#         SSA  Surface Albedo     Pressure  Precipitable Water  Wind Direction  \
# 0  0.944634        0.073616  1014.075228            2.059589      206.121918
# 1  0.946338        0.076849  1015.326826            1.931655      205.129909
# 2  0.948031        0.129397  1015.289041            1.977534      206.482192
# 3  0.942675        0.126356  1015.489384            1.877785      210.213927
# 4  0.939269        0.097205  1015.271689            2.004075      210.686758
#
#    Wind Speed  Global Horizontal UV Irradiance (280-400nm)  \
# 0    2.277717                                   84254.7112
# 1    2.438208                                   89209.9887
# 2    2.402511                                   84675.6378
# 3    2.234212                                   89718.0624
# 4    2.410491                                   87641.0280
#
#    Global Horizontal UV Irradiance (295-385nm)  Year
# 0                                   65990.9163  1998
# 1                                   69872.0801  1999
# 2                                   66309.0552  2000
# 3                                   70267.4083  2001
# 4                                   68647.5712  2002
#
# [5 rows x 22 columns]
#        Temperature  Aerosol Optical Depth   Clearsky DHI  Clearsky DNI  \
# count    27.000000              27.000000      27.000000  2.700000e+01
# mean     11.937903               0.137030  415994.592593  2.922834e+06
# std       0.638105               0.015832   20579.323324  4.970088e+04
# min      10.588527               0.113417  379813.000000  2.820769e+06
# 25%      11.652671               0.122459  397834.500000  2.887178e+06
# 50%      12.035833               0.135594  409939.000000  2.917497e+06
# 75%      12.365011               0.149557  430761.500000  2.964661e+06
# max      12.944326               0.164721  460958.000000  3.009470e+06
#
#        Clearsky GHI  Dew Point            DHI           DNI           GHI  \
# count  2.700000e+01  27.000000      27.000000  2.700000e+01  2.700000e+01
# mean   2.023211e+06   8.070357  624842.333333  1.503138e+06  1.472056e+06
# std    8.866378e+03   0.683180   48211.985775  1.379306e+05  6.427598e+04
# min    2.009153e+06   6.830057  533885.000000  1.284494e+06  1.314211e+06
# 25%    2.016904e+06   7.632905  593395.000000  1.409616e+06  1.431207e+06
# 50%    2.021066e+06   7.914555  626211.000000  1.509102e+06  1.478612e+06
# 75%    2.029890e+06   8.707791  647325.500000  1.587368e+06  1.509034e+06
# max    2.042209e+06   9.319372  715198.000000  1.785651e+06  1.598940e+06
#
#            Ozone  Relative Humidity  Solar Zenith Angle        SSA  \
# count  27.000000          27.000000           27.000000  27.000000
# mean    0.318857          79.260992           89.665968   0.936683
# std     0.005170           2.187101            0.014457   0.004867
# min     0.309222          74.923473           89.657018   0.930409
# 25%     0.315601          78.469277           89.657496   0.933233
# 50%     0.317785          79.054800           89.657670   0.935155
# 75%     0.320963          80.881344           89.673899   0.939463
# max     0.333537          82.964814           89.690812   0.948031
#
#        Surface Albedo     Pressure  Precipitable Water  Wind Direction  \
# count       27.000000    27.000000           27.000000       27.000000
# mean         0.118827  1014.945819            2.102144      205.267728
# std          0.027945     0.895729            0.104097        5.599962
# min          0.073616  1011.824658            1.877785      194.877968
# 25%          0.095877  1014.510103            2.033299      201.931906
# 50%          0.124082  1015.131849            2.093756      205.129909
# 75%          0.133164  1015.450400            2.155776      209.543151
# max          0.172849  1016.366553            2.357842      220.440753
#
#        Wind Speed  Global Horizontal UV Irradiance (280-400nm)  \
# count   27.000000                                    27.000000
# mean     2.374088                                 82667.858733
# std      0.079190                                  3640.863514
# min      2.234212                                 73705.570800
# 25%      2.318790                                 80300.912250
# 50%      2.361849                                 83067.640500
# 75%      2.416033                                 84758.532150
# max      2.560320                                 89718.062400
#
#        Global Horizontal UV Irradiance (295-385nm)
# count                                    27.000000
# mean                                  64749.274341
# std                                    2852.257569
# min                                   57729.626000
# 25%                                   62897.635950
# 50%                                   65072.933600
# 75%                                   66382.727700
# max                                   70267.408300
#                                              Temperature  \
# Temperature                                     1.000000
# Aerosol Optical Depth                          -0.197294
# Clearsky DHI                                   -0.379959
# Clearsky DNI                                    0.263769
# Clearsky GHI                                   -0.066787
# Dew Point                                       0.703338
# DHI                                            -0.494297
# DNI                                             0.449569
# GHI                                             0.181431
# Ozone                                          -0.095066
# Relative Humidity                              -0.264472
# Solar Zenith Angle                              0.189404
# SSA                                            -0.425474
# Surface Albedo                                 -0.558139
# Pressure                                       -0.213358
# Precipitable Water                              0.246499
# Wind Direction                                  0.021515
# Wind Speed                                      0.042175
# Global Horizontal UV Irradiance (280-400nm)     0.174213
# Global Horizontal UV Irradiance (295-385nm)     0.174555
#
#                                              Aerosol Optical Depth  \
# Temperature                                              -0.197294
# Aerosol Optical Depth                                     1.000000
# Clearsky DHI                                              0.969922
# Clearsky DNI                                             -0.953985
# Clearsky GHI                                             -0.709681
# Dew Point                                                -0.053241
# DHI                                                       0.101896
# DNI                                                       0.012462
# GHI                                                       0.066207
# Ozone                                                    -0.073584
# Relative Humidity                                         0.193822
# Solar Zenith Angle                                       -0.068975
# SSA                                                       0.440321
# Surface Albedo                                            0.053927
# Pressure                                                 -0.123590
# Precipitable Water                                       -0.243394
# Wind Direction                                            0.004917
# Wind Speed                                               -0.374063
# Global Horizontal UV Irradiance (280-400nm)               0.065925
# Global Horizontal UV Irradiance (295-385nm)               0.065745
#
#                                              Clearsky DHI  Clearsky DNI  \
# Temperature                                     -0.379959      0.263769
# Aerosol Optical Depth                            0.969922     -0.953985
# Clearsky DHI                                     1.000000     -0.968575
# Clearsky DNI                                    -0.968575      1.000000
# Clearsky GHI                                    -0.688842      0.835877
# Dew Point                                       -0.158846     -0.052561
# DHI                                              0.150488     -0.053540
# DNI                                             -0.079902      0.157512
# GHI                                             -0.020869      0.185622
# Ozone                                           -0.040389      0.089727
# Relative Humidity                                0.272639     -0.413792
# Solar Zenith Angle                              -0.104340      0.013558
# SSA                                              0.497971     -0.398858
# Surface Albedo                                   0.196535     -0.114865
# Pressure                                        -0.042423      0.049611
# Precipitable Water                              -0.220098      0.035098
# Wind Direction                                  -0.042961      0.121477
# Wind Speed                                      -0.291490      0.253410
# Global Horizontal UV Irradiance (280-400nm)     -0.021648      0.185171
# Global Horizontal UV Irradiance (295-385nm)     -0.021997      0.185405
#
#                                              Clearsky GHI  Dew Point  \
# Temperature                                     -0.066787   0.703338
# Aerosol Optical Depth                           -0.709681  -0.053241
# Clearsky DHI                                    -0.688842  -0.158846
# Clearsky DNI                                     0.835877  -0.052561
# Clearsky GHI                                     1.000000  -0.517816
# Dew Point                                       -0.517816   1.000000
# DHI                                              0.210019  -0.396680
# DNI                                              0.250329  -0.160607
# GHI                                              0.498074  -0.491712
# Ozone                                            0.088254  -0.165829
# Relative Humidity                               -0.629091   0.497925
# Solar Zenith Angle                              -0.178964   0.148002
# SSA                                             -0.058267  -0.518137
# Surface Albedo                                   0.036176  -0.258157
# Pressure                                         0.058095  -0.194561
# Precipitable Water                              -0.424904   0.746997
# Wind Direction                                   0.261554  -0.187190
# Wind Speed                                      -0.002028   0.119650
# Global Horizontal UV Irradiance (280-400nm)      0.499143  -0.495227
# Global Horizontal UV Irradiance (295-385nm)      0.499236  -0.494964
#
#                                                   DHI       DNI       GHI  \
# Temperature                                 -0.494297  0.449569  0.181431
# Aerosol Optical Depth                        0.101896  0.012462  0.066207
# Clearsky DHI                                 0.150488 -0.079902 -0.020869
# Clearsky DNI                                -0.053540  0.157512  0.185622
# Clearsky GHI                                 0.210019  0.250329  0.498074
# Dew Point                                   -0.396680 -0.160607 -0.491712
# DHI                                          1.000000 -0.568088  0.115753
# DNI                                         -0.568088  1.000000  0.740893
# GHI                                          0.115753  0.740893  1.000000
# Ozone                                       -0.024085  0.161111  0.095205
# Relative Humidity                            0.082910 -0.769580 -0.879796
# Solar Zenith Angle                          -0.184914  0.158327  0.035753
# SSA                                          0.019950  0.262966  0.250361
# Surface Albedo                               0.465621 -0.482483 -0.236587
# Pressure                                    -0.121393  0.016918 -0.059202
# Precipitable Water                          -0.271897 -0.490809 -0.798020
# Wind Direction                               0.416827 -0.004561  0.350928
# Wind Speed                                  -0.522001  0.078573 -0.359145
# Global Horizontal UV Irradiance (280-400nm)  0.125515  0.730824  0.999367
# Global Horizontal UV Irradiance (295-385nm)  0.125725  0.730455  0.999318
#
#                                                 Ozone  Relative Humidity  \
# Temperature                                 -0.095066          -0.264472
# Aerosol Optical Depth                       -0.073584           0.193822
# Clearsky DHI                                -0.040389           0.272639
# Clearsky DNI                                 0.089727          -0.413792
# Clearsky GHI                                 0.088254          -0.629091
# Dew Point                                   -0.165829           0.497925
# DHI                                         -0.024085           0.082910
# DNI                                          0.161111          -0.769580
# GHI                                          0.095205          -0.879796
# Ozone                                        1.000000          -0.107315
# Relative Humidity                           -0.107315           1.000000
# Solar Zenith Angle                          -0.018158          -0.047314
# SSA                                          0.099922          -0.167557
# Surface Albedo                               0.169312           0.343234
# Pressure                                    -0.255841          -0.021340
# Precipitable Water                          -0.100273           0.704719
# Wind Direction                               0.052202          -0.278821
# Wind Speed                                   0.082258           0.097468
# Global Horizontal UV Irradiance (280-400nm)  0.083250          -0.875949
# Global Horizontal UV Irradiance (295-385nm)  0.082691          -0.876004
#
#                                              Solar Zenith Angle       SSA  \
# Temperature                                            0.189404 -0.425474
# Aerosol Optical Depth                                 -0.068975  0.440321
# Clearsky DHI                                          -0.104340  0.497971
# Clearsky DNI                                           0.013558 -0.398858
# Clearsky GHI                                          -0.178964 -0.058267
# Dew Point                                              0.148002 -0.518137
# DHI                                                   -0.184914  0.019950
# DNI                                                    0.158327  0.262966
# GHI                                                    0.035753  0.250361
# Ozone                                                 -0.018158  0.099922
# Relative Humidity                                     -0.047314 -0.167557
# Solar Zenith Angle                                     1.000000 -0.032731
# SSA                                                   -0.032731  1.000000
# Surface Albedo                                        -0.219591 -0.151058
# Pressure                                               0.098873  0.102302
# Precipitable Water                                     0.040800 -0.533345
# Wind Direction                                        -0.320357 -0.026026
# Wind Speed                                            -0.001908 -0.066673
# Global Horizontal UV Irradiance (280-400nm)            0.048322  0.242638
# Global Horizontal UV Irradiance (295-385nm)            0.048353  0.241758
#
#                                              Surface Albedo  Pressure  \
# Temperature                                       -0.558139 -0.213358
# Aerosol Optical Depth                              0.053927 -0.123590
# Clearsky DHI                                       0.196535 -0.042423
# Clearsky DNI                                      -0.114865  0.049611
# Clearsky GHI                                       0.036176  0.058095
# Dew Point                                         -0.258157 -0.194561
# DHI                                                0.465621 -0.121393
# DNI                                               -0.482483  0.016918
# GHI                                               -0.236587 -0.059202
# Ozone                                              0.169312 -0.255841
# Relative Humidity                                  0.343234 -0.021340
# Solar Zenith Angle                                -0.219591  0.098873
# SSA                                               -0.151058  0.102302
# Surface Albedo                                     1.000000  0.089948
# Pressure                                           0.089948  1.000000
# Precipitable Water                                 0.174182  0.180113
# Wind Direction                                    -0.080443 -0.375446
# Wind Speed                                        -0.092506  0.255826
# Global Horizontal UV Irradiance (280-400nm)       -0.236892 -0.055850
# Global Horizontal UV Irradiance (295-385nm)       -0.237244 -0.055716
#
#                                              Precipitable Water  \
# Temperature                                            0.246499
# Aerosol Optical Depth                                 -0.243394
# Clearsky DHI                                          -0.220098
# Clearsky DNI                                           0.035098
# Clearsky GHI                                          -0.424904
# Dew Point                                              0.746997
# DHI                                                   -0.271897
# DNI                                                   -0.490809
# GHI                                                   -0.798020
# Ozone                                                 -0.100273
# Relative Humidity                                      0.704719
# Solar Zenith Angle                                     0.040800
# SSA                                                   -0.533345
# Surface Albedo                                         0.174182
# Pressure                                               0.180113
# Precipitable Water                                     1.000000
# Wind Direction                                        -0.369174
# Wind Speed                                             0.429119
# Global Horizontal UV Irradiance (280-400nm)           -0.800823
# Global Horizontal UV Irradiance (295-385nm)           -0.800639
#
#                                              Wind Direction  Wind Speed  \
# Temperature                                        0.021515    0.042175
# Aerosol Optical Depth                              0.004917   -0.374063
# Clearsky DHI                                      -0.042961   -0.291490
# Clearsky DNI                                       0.121477    0.253410
# Clearsky GHI                                       0.261554   -0.002028
# Dew Point                                         -0.187190    0.119650
# DHI                                                0.416827   -0.522001
# DNI                                               -0.004561    0.078573
# GHI                                                0.350928   -0.359145
# Ozone                                              0.052202    0.082258
# Relative Humidity                                 -0.278821    0.097468
# Solar Zenith Angle                                -0.320357   -0.001908
# SSA                                               -0.026026   -0.066673
# Surface Albedo                                    -0.080443   -0.092506
# Pressure                                          -0.375446    0.255826
# Precipitable Water                                -0.369174    0.429119
# Wind Direction                                     1.000000   -0.179718
# Wind Speed                                        -0.179718    1.000000
# Global Horizontal UV Irradiance (280-400nm)        0.351831   -0.371002
# Global Horizontal UV Irradiance (295-385nm)        0.352022   -0.371254
#
#                                              Global Horizontal UV Irradiance (280-400nm)  \
# Temperature                                                                     0.174213
# Aerosol Optical Depth                                                           0.065925
# Clearsky DHI                                                                   -0.021648
# Clearsky DNI                                                                    0.185171
# Clearsky GHI                                                                    0.499143
# Dew Point                                                                      -0.495227
# DHI                                                                             0.125515
# DNI                                                                             0.730824
# GHI                                                                             0.999367
# Ozone                                                                           0.083250
# Relative Humidity                                                              -0.875949
# Solar Zenith Angle                                                              0.048322
# SSA                                                                             0.242638
# Surface Albedo                                                                 -0.236892
# Pressure                                                                       -0.055850
# Precipitable Water                                                             -0.800823
# Wind Direction                                                                  0.351831
# Wind Speed                                                                     -0.371002
# Global Horizontal UV Irradiance (280-400nm)                                     1.000000
# Global Horizontal UV Irradiance (295-385nm)                                     0.999998
#
#                                              Global Horizontal UV Irradiance (295-385nm)
# Temperature                                                                     0.174555
# Aerosol Optical Depth                                                           0.065745
# Clearsky DHI                                                                   -0.021997
# Clearsky DNI                                                                    0.185405
# Clearsky GHI                                                                    0.499236
# Dew Point                                                                      -0.494964
# DHI                                                                             0.125725
# DNI                                                                             0.730455
# GHI                                                                             0.999318
# Ozone                                                                           0.082691
# Relative Humidity                                                              -0.876004
# Solar Zenith Angle                                                              0.048353
# SSA                                                                             0.241758
# Surface Albedo                                                                 -0.237244
# Pressure                                                                       -0.055716
# Precipitable Water                                                             -0.800639
# Wind Direction                                                                  0.352022
# Wind Speed                                                                     -0.371254
# Global Horizontal UV Irradiance (280-400nm)                                     0.999998
# Global Horizontal UV Irradiance (295-385nm)                                     1.000000

# %% [markdown]
# This code block generates **Scatter Plots for Visualizing Relationships**.
#
# *   `import matplotlib.pyplot as plt`: Imports Matplotlib, a plotting library.
# *   The code then generates two scatter plots:
#     *   `ARMS` vs `AGE`
#     *   `ARMS` vs `BMI`
# *   Each plot shows the relationship between the dependent variable (`ARMS`) and one predictor (`AGE` or `BMI`), helping to visually assess linearity, direction, strength, and identify potential outliers or patterns.
#
# **Role in Regression:** Scatter plots are fundamental for visually inspecting the relationship between the dependent variable and each independent variable. They help confirm linearity assumptions, identify non-linear patterns, or detect influential outliers that might impact the regression model. This visual check is crucial for guiding variable transformations or model selection.

# %%
import matplotlib.pyplot as plt

# Wind Speed vs Wind Direction
plt.figure()
plt.scatter(ny_df["GHI"], ny_df["Temperature"])
plt.xlabel("GHI")
plt.ylabel("Temperature")
plt.title("Scatter Plot of GHI vs Temperature (NY)")
plt.show()

# Wind Speed vs GHI (with line of best fit)
plt.figure()
x = np.array(ny_df["GHI"])
y = np.array(ny_df["Relative Humidity"])
plt.scatter(x, y)
a, b = np.polyfit(x, y, 1)
plt.plot(x, a*x+b)
plt.xlabel("GHI")
plt.ylabel("Relative Humidity")
plt.title("Scatter Plot of GHI vs Relative Humidity (NY)")
plt.show()

# %% [markdown]
# Check for Multicollinearity: VIF (Variance Inflation Factor)

# %% [markdown]
# This code block calculates the **Variance Inflation Factor (VIF)**.
#
# *   `import statsmodels.api as sm` and `from statsmodels.stats.outliers_influence import variance_inflation_factor`: Imports necessary libraries for statistical modeling and VIF calculation.
# *   `X = df[["AGE", "BMI", "SEX", "IPAQ"]].dropna()`: Selects the independent variables and removes any rows with missing values.
# *   `X = sm.add_constant(X)`: Adds a constant (intercept) term to the predictor matrix, which is required for `statsmodels` to correctly calculate VIF (and later for the regression model).
# *   The loop then calculates the VIF for each predictor variable. VIF measures how much the variance of an estimated regression coefficient is inflated due to multicollinearity.
# *   `print(vif_data)`: Displays a DataFrame showing each variable and its corresponding VIF.
#
# **Role in Regression:** Multicollinearity (high correlation between independent variables) can make regression coefficients unstable and difficult to interpret. High VIF values (e.g., typically above 5 or 10) indicate significant multicollinearity, suggesting that these variables provide redundant information. Addressing multicollinearity (e.g., by removing one of the correlated variables or combining them) can improve model stability and interpretability.

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Select predictor variables
X = ny_df[["Aerosol Optical Depth",	"Ozone",	"Relative Humidity",	"Solar Zenith Angle",	"SSA",	"Surface Albedo",	"Pressure", "Wind Direction",	"Wind Speed"]].dropna()

# Add constant (intercept)
X = sm.add_constant(X)

# Compute VIF for each predictor
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
#                 Variable           VIF
# 0                  const  5.115955e+07
# 1  Aerosol Optical Depth  1.719525e+00
# 2                  Ozone  1.298552e+00
# 3      Relative Humidity  1.524777e+00
# 4     Solar Zenith Angle  1.232454e+00
# 5                    SSA  1.523717e+00
# 6         Surface Albedo  1.434001e+00
# 7               Pressure  1.522475e+00
# 8         Wind Direction  1.477780e+00
# 9             Wind Speed  1.406371e+00

# %% [markdown]
# OLS Regression Results

# %% [markdown]
# This code block fits an **Ordinary Least Squares (OLS) Regression Model**.
#
# *   `import statsmodels.formula.api as smf`: Imports the formula API from `statsmodels`, which allows you to define models using R-style formulas.
# *   `model = smf.ols("ARMS ~ AGE+ BMI+ SEX + IPAQ", data=df).fit()`: This is the core line for building the linear regression model. It specifies that `ARMS` is the dependent variable, and `AGE`, `BMI`, `SEX`, and `IPAQ` are the independent variables. The `.fit()` method estimates the model parameters.
# *   `print(model.summary())`: Prints a comprehensive summary of the regression model. This summary includes:
#     *   **R-squared and Adj. R-squared**: Measures the proportion of variance in the dependent variable explained by the independent variables.
#     *   **F-statistic and Prob (F-statistic)**: Tests the overall significance of the regression model.
#     *   **Coefficients (coef)**: The estimated effect of each independent variable on the dependent variable.
#     *   **Standard Errors (std err)**: Measures the precision of the coefficient estimates.
#     *   **t-values and P-values (P>|t|)**: Tests the statistical significance of each individual coefficient.
#     *   **Confidence Intervals ([0.025 0.975])**: Provides a range within which the true coefficient likely lies.
#     *   **Omnibus, Durbin-Watson, Jarque-Bera, Skew, Kurtosis**: Diagnostics for model assumptions, particularly about residuals.
#
# **Role in Regression:** This is the primary step of building the regression model. The output provides all the critical information to interpret the model, assess the significance of predictors, and evaluate its overall fit and explanatory power.

# %%
import statsmodels.formula.api as smf
model = smf.ols("GHI ~ Q('Aerosol Optical Depth') + Ozone + Q('Relative Humidity') +	Q('Solar Zenith Angle') + SSA + Q('Surface Albedo') + Pressure + Q('Wind Direction')	+ Q('Wind Speed')", data=ny_df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GHI   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     13.80
# Date:                Thu, 04 Dec 2025   Prob (F-statistic):           3.55e-06
# Time:                        13:15:57   Log-Likelihood:                -308.14
# No. Observations:                  27   AIC:                             636.3
# Df Residuals:                      17   BIC:                             649.2
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                  -1.734e+07    3.8e+07     -0.457      0.654   -9.74e+07    6.28e+07
# Q('Aerosol Optical Depth')  6.022e+05   4.48e+05      1.344      0.197   -3.43e+05    1.55e+06
# Ozone                       2.185e+05   1.19e+06      0.183      0.857    -2.3e+06    2.73e+06
# Q('Relative Humidity')     -2.556e+04   3053.828     -8.370      0.000    -3.2e+04   -1.91e+04
# Q('Solar Zenith Angle')      2.11e+05   4.15e+05      0.508      0.618   -6.65e+05    1.09e+06
# SSA                         4.547e+05   1.37e+06      0.331      0.744   -2.44e+06    3.35e+06
# Q('Surface Albedo')         1.246e+05   2.32e+05      0.537      0.598   -3.64e+05    6.14e+05
# Pressure                    1461.6608   7450.899      0.196      0.847   -1.43e+04    1.72e+04
# Q('Wind Direction')         1134.9573   1174.167      0.967      0.347   -1342.320    3612.234
# Q('Wind Speed')            -1.626e+05    8.1e+04     -2.008      0.061   -3.34e+05    8254.713
# ==============================================================================
# Omnibus:                        0.057   Durbin-Watson:                   1.605
# Prob(Omnibus):                  0.972   Jarque-Bera (JB):                0.272
# Skew:                           0.033   Prob(JB):                        0.873
# Kurtosis:                       2.513   Cond. No.                     7.46e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.46e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# This code block performs an **ANOVA (Analysis of Variance) for the OLS Model**.
#
# *   `from statsmodels.stats.anova import anova_lm`: Imports the function to perform ANOVA on a linear model.
# *   `anova_results = anova_lm(model, typ=2)`: Calculates the ANOVA table using Type II sum of squares, which is appropriate for balanced and unbalanced designs.
# *   `print(anova_results)`: Displays the ANOVA table, showing the sum of squares, degrees of freedom, F-statistics, and p-values for each predictor. This helps in understanding the unique contribution of each variable to the model's explanatory power.
# *   The subsequent lines calculate `SS_regression`, `SS_residual`, and `SS_total`. These are the sum of squares due to regression, residuals, and total variation, respectively. They are fundamental components for understanding the partitioning of variance in the dependent variable.
#
# **Role in Regression:** ANOVA provides an alternative way to assess the statistical significance of the independent variables and the overall model. It breaks down the total variability in the dependent variable into parts explained by the model (regression) and parts unexplained (residual). This helps confirm the findings from the `model.summary()` regarding predictor importance and model fit.

# %%
from statsmodels.stats.anova import anova_lm

anova_results = anova_lm(model, typ=2)
print(anova_results)

SS_regression = anova_results["sum_sq"][:-1].sum()   # sum of all predictors
SS_residual   = anova_results.loc["Residual", "sum_sq"]
SS_total      = SS_regression + SS_residual

print("SS_regression:", SS_regression)
print("SS_residual:", SS_residual)
print("SS_total:", SS_total)
# Out:
#                                   sum_sq    df          F        PR(>F)
# Q('Aerosol Optical Depth')  1.374531e+09   1.0   1.807010  1.965323e-01
# Ozone                       2.554477e+07   1.0   0.033582  8.567664e-01
# Q('Relative Humidity')      5.328466e+10   1.0  70.050015  1.962889e-07
# Q('Solar Zenith Angle')     1.962774e+08   1.0   0.258034  6.180018e-01
# SSA                         8.356596e+07   1.0   0.109859  7.443557e-01
# Q('Surface Albedo')         2.196926e+08   1.0   0.288816  5.979452e-01
# Pressure                    2.927317e+07   1.0   0.038484  8.468011e-01
# Q('Wind Direction')         7.107107e+08   1.0   0.934327  3.472920e-01
# Q('Wind Speed')             3.066768e+09   1.0   4.031689  6.081672e-02
# Residual                    1.293132e+10  17.0        NaN           NaN
# SS_regression: 58991019889.17006
# SS_residual: 12931319817.286383
# SS_total: 71922339706.45644

# %% [markdown]
# This code block generates **Diagnostic Plots for OLS Residuals**.
#
# *   `fitted = model.fittedvalues`: Extracts the predicted values (fitted values) from the OLS model.
# *   `resid = model.resid`: Extracts the residuals (observed - predicted values) from the OLS model.
# *   **Residuals vs Fitted Plot**: `plt.scatter(fitted, resid)` creates a scatter plot of residuals against fitted values. This plot helps check the assumption of homoscedasticity (constant variance of residuals) and linearity. Ideally, residuals should be randomly scattered around zero, with no discernible pattern.
# *   **Normal Q-Q Plot**: `sm.qqplot(resid, line='45')` generates a Quantile-Quantile plot. This plot compares the distribution of the residuals to a normal distribution. If the residuals are normally distributed, the points should fall approximately along the 45-degree line.
#
# **Role in Regression:** These plots are crucial for assessing the fundamental assumptions of linear regression: homoscedasticity, linearity, and normality of residuals. Violations of these assumptions can lead to biased standard errors, incorrect p-values, and ultimately, unreliable model inferences. Identifying issues here guides further model refinement or alternative modeling approaches.

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm

# residuals vs fitted
fitted = model.fittedvalues
resid = model.resid
plt.scatter(fitted, resid)
plt.axhline(0, linestyle='--')
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
plt.title('Residuals vs Fitted')
plt.show()

# QQ plot
sm.qqplot(resid, line='45')
plt.title('Normal Q-Q')
plt.show()

# %% [markdown]
# This code block refines the **Diagnostic Plots using Standardized Residuals**.
#
# *   `standardized_residuals = model.get_influence().resid_studentized_internal`: Calculates standardized (studentized internal) residuals. Standardizing residuals helps to make them comparable across different observations and makes it easier to spot outliers.
# *   **Standardized Residuals vs Fitted Plot**: Similar to the previous residuals vs fitted plot, but using standardized residuals. This plot is often preferred for checking homoscedasticity as it normalizes the y-axis, making it easier to identify patterns or fanning out of residuals.
# *   **QQ Plot of Standardized Residuals**: Another QQ plot, this time using standardized residuals. This provides a clearer assessment of the normality assumption, as standardized residuals should follow a standard normal distribution (mean 0, standard deviation 1).
#
# **Role in Regression:** These standardized residual plots offer a more robust way to check for heteroscedasticity and non-normality. Standardized residuals are particularly useful for identifying potential outliers or influential data points, as residuals exceeding certain thresholds (e.g., +/- 2 or 3) are considered unusual.

# %%
import numpy as np

standardized_residuals = model.get_influence().resid_studentized_internal

plt.figure(figsize=(7, 5))
plt.scatter(model.fittedvalues, standardized_residuals)
plt.axhline(0)
plt.xlabel("Fitted values")
plt.ylabel("Standardized residuals")
plt.title("Standardized Residuals vs Fitted")
plt.show()

# 2. Fit the original model
model = smf.ols("GHI ~ Q('Aerosol Optical Depth') +	Ozone + Q('Relative Humidity') +	Q('Solar Zenith Angle') + SSA + Q('Surface Albedo') + Pressure + Q('Wind Direction')	+ Q('Wind Speed')", data=ny_df).fit()

# 3. Get standardized (studentized internal) residuals
influence = model.get_influence()
std_resid = influence.resid_studentized_internal

# 4. QQ plot using standardized residuals
fig = sm.qqplot(std_resid, line="45")
plt.title("QQ Plot of Standardized Residuals ")
plt.show()

# %% [markdown]
# This code block performs the **Breusch-Pagan Test for Heteroscedasticity**.
#
# *   `from statsmodels.stats.diagnostic import het_breuschpagan`: Imports the `het_breuschpagan` function for the test.
# *   `bp_test = het_breuschpagan(model.resid, model.model.exog)`: Executes the Breusch-Pagan test. It takes the residuals and the design matrix (exogenous variables) of the model as input. This test formally checks if the variance of the residuals is constant across all levels of the independent variables.
# *   `bp_labels = [...]` and `print(dict(zip(bp_labels, bp_test)))`: Formats and prints the results of the test, including the LM Statistic, its p-value, the F Statistic, and its p-value.
#
# **Role in Regression:** The Breusch-Pagan test provides a statistical (rather than just visual) confirmation for the assumption of homoscedasticity. A low p-value (typically < 0.05) indicates that heteroscedasticity is present, meaning the variance of residuals is not constant. If heteroscedasticity is detected, it suggests that the standard OLS estimates might be inefficient, and Weighted Least Squares (WLS) or robust standard errors might be more appropriate.

# %%
from statsmodels.stats.diagnostic import het_breuschpagan

bp_test = het_breuschpagan(model.resid, model.model.exog)

bp_labels = ["LM Statistic", "LM p-value", "F Statistic", "F p-value"]
print(dict(zip(bp_labels, bp_test)))
# Out:
# {'LM Statistic': np.float64(6.213346977615656), 'LM p-value': np.float64(0.7183903004907235), 'F Statistic': np.float64(0.5646085522373986), 'F p-value': np.float64(0.8074077968056196)}

# %% [markdown]
# This code block **Identifies an Outlier based on Residuals**.
#
# *   `outlier_index = np.argmin(model.resid)`: Finds the index of the observation with the smallest residual. This identifies the observation where the model's prediction was furthest below the actual value.
# *   `df.iloc[outlier_index]`: Displays the entire row of data for that identified outlier.
#
# **Role in Regression:** Identifying outliers is an important part of regression diagnostics. Outliers can heavily influence the estimated regression coefficients and the overall fit of the model. Understanding the characteristics of these outliers can inform decisions about whether to remove them, transform the data, or use more robust regression techniques.

# %%
import numpy as np

outlier_index = np.argmin(model.resid)
ny_df.iloc[outlier_index]
# Out:
# Temperature                                    1.113815e+01
# Aerosol Optical Depth                          1.355938e-01
# Asymmetry                                      6.032055e-01
# Clearsky DHI                                   4.217080e+05
# Clearsky DNI                                   2.904239e+06
# Clearsky GHI                                   2.023100e+06
# Dew Point                                      7.717511e+00
# DHI                                            6.211380e+05
# DNI                                            1.359752e+06
# GHI                                            1.376473e+06
# Ozone                                          3.176121e-01
# Relative Humidity                              8.097952e+01
# Solar Zenith Angle                             8.965758e+01
# SSA                                            9.396575e-01
# Surface Albedo                                 1.345753e-01
# Pressure                                       1.014879e+03
# Precipitable Water                             2.080479e+00
# Wind Direction                                 1.994124e+02
# Wind Speed                                     2.361849e+00
# Global Horizontal UV Irradiance (280-400nm)    7.718051e+04
# Global Horizontal UV Irradiance (295-385nm)    6.044567e+04
# Year                                           2.009000e+03
# Name: 11, dtype: float64

# %% [markdown]
# This code block performs **Weighted Least Squares (WLS) Regression**.
#
# *   **Step 1: Fit OLS first**: An initial OLS model is fitted to get the residuals.
# *   **Step 2: Model the variance**: The squared residuals (`resid_sq = ols_model.resid**2`) are used as a proxy for the variance. Another OLS model is then fitted to predict `resid_sq` using the `fittedvalues` from the first OLS model. This helps model how the variance changes with the predicted values.
# *   **Step 3: Define weights**: The weights for WLS are calculated as the inverse of the predicted variance (`weights = 1 / variance_model.fittedvalues`). Observations with higher predicted variance (i.e., where heteroscedasticity is more pronounced) will receive lower weights, and vice-versa.
# *   **Fit WLS model**: Finally, `sm.WLS(y, X, weights=weights).fit()` fits the Weighted Least Squares model using the calculated weights. This model attempts to correct for heteroscedasticity by giving less influence to observations with larger residual variance.
# *   `print(wls_model.summary())`: Prints the summary of the WLS model, which has a similar structure to the OLS summary, but with potentially more efficient and reliable coefficient estimates and standard errors in the presence of heteroscedasticity.
#
# **Role in Regression:** WLS regression is a technique used when the assumption of homoscedasticity (constant variance of residuals) is violated. By weighting observations inversely to their residual variance, WLS provides more efficient (lower variance) coefficient estimates than OLS when heteroscedasticity is present. This leads to more reliable hypothesis tests and confidence intervals for the regression coefficients.

# %% [markdown]
# This text cell introduces the Weighted Least Squares (WLS) Regression, often used when heteroscedasticity is detected.

# %% [markdown]
# WLS Regression Results

# %%
import numpy as np
import statsmodels.api as sm

# Step 1: Fit OLS first
X = ny_df[["Aerosol Optical Depth",	"DNI",	"Ozone",	"Relative Humidity",	"Solar Zenith Angle",	"SSA",	"Surface Albedo",	"Pressure", "Wind Direction",	"Wind Speed"]]
X = sm.add_constant(X)
y = ny_df["GHI"]

ols_model = sm.OLS(y, X).fit()

# Step 2: Model the variance
resid_sq = ols_model.resid**2
variance_model = sm.OLS(resid_sq, sm.add_constant(ols_model.fittedvalues)).fit()

# Step 3: Define weights
weights = 1 / variance_model.fittedvalues

# Fit WLS model
wls_model = sm.WLS(y, X, weights=weights).fit()

print(wls_model.summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                    GHI   R-squared:                       0.919
# Model:                            WLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                     18.24
# Date:                Thu, 04 Dec 2025   Prob (F-statistic):           6.57e-07
# Time:                        13:16:48   Log-Likelihood:                -302.90
# No. Observations:                  27   AIC:                             627.8
# Df Residuals:                      16   BIC:                             642.1
# Df Model:                          10
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -1.912e+07   3.23e+07     -0.592      0.562   -8.76e+07    4.93e+07
# Aerosol Optical Depth  1.667e+05   4.27e+05      0.390      0.701   -7.39e+05    1.07e+06
# DNI                       0.1970      0.071      2.774      0.014       0.046       0.348
# Ozone                 -3.557e+05   1.03e+06     -0.346      0.734   -2.53e+06    1.82e+06
# Relative Humidity     -1.561e+04   4554.704     -3.428      0.003   -2.53e+04   -5958.564
# Solar Zenith Angle     1.984e+05   3.54e+05      0.561      0.583   -5.52e+05    9.49e+05
# SSA                    5.587e+05   1.18e+06      0.472      0.643   -1.95e+06    3.07e+06
# Surface Albedo         3.608e+05   2.13e+05      1.697      0.109   -8.99e+04    8.12e+05
# Pressure               3293.0422   6375.975      0.516      0.613   -1.02e+04    1.68e+04
# Wind Direction         2359.2119   1075.533      2.194      0.043      79.184    4639.239
# Wind Speed             -2.37e+05   7.42e+04     -3.194      0.006   -3.94e+05   -7.97e+04
# ==============================================================================
# Omnibus:                        0.544   Durbin-Watson:                   1.345
# Prob(Omnibus):                  0.762   Jarque-Bera (JB):                0.624
# Skew:                          -0.106   Prob(JB):                        0.732
# Kurtosis:                       2.286   Cond. No.                     1.08e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.62e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# **Little notes**
# Autocorrelation refers to the degree of similarity or correlation between values of the same variable at different points in time, particularly in time series data.
#
#
#
# The Durbin-Watson test statistic implies the presence and type of first-order autocorrelation in regression residuals:
#
# Value close to 2: Indicates no significant autocorrelation, implying that the model’s residuals are independent, which satisfies a key assumption of ordinary least squares (OLS) regression.
# Substantially less than 2 (e.g., below 1.5): Suggests positive autocorrelation, meaning consecutive residuals are positively correlated. This often occurs in time series data where errors persist over time, potentially due to omitted lagged variables or model misspecification. It can lead to underestimated standard errors and inflated significance of predictors.
# Substantially greater than 2 (e.g., above 2.5): Indicates negative autocorrelation, where residuals alternate in sign more than expected, possibly due to over-adjustment in the model or unmodeled cyclical patterns.
